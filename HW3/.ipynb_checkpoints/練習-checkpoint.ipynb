# %%
#抓取NBA聯合新聞網的網頁原始碼(HTML)

import urllib.request as req
url="https://nba.udn.com/nba/index"
with req.urlopen(url) as response:
    data=response.read().decode("utf-8")
print(data)
# Out:
# <!DOCTYPE html><html lang="zh-TW"><!--total：0.0027--><head><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, target-densityDpi=device-dpi" /><meta charset="utf-8" /><!-- favicon --><link rel="shortcut icon" type="image/x-icon" href="/favicon.ico" /><link rel="icon" type="image/x-icon" href="/favicon.ico" /><link rel="apple-touch-icon" href="/favicon.ico" /><!-- for twitter--><meta name="twitter:card" content="summary" /><!-- for Facebook --><meta property="og:title" content="udn NBA | 聯合新聞網"/><meta property="og:type" content="website"/><meta property="og:url" content="https://nba.udn.com/nba/index"/><meta property="og:image" content="https://nba.udn.com/img/og_image.jpg"/><meta property="og:site_name" content="udn NBA"/><meta property="og:description" content="提供NBA美國職籃完整資訊，包含最新消息、球員數據、賽程比分、名家專欄等內容。"/><meta property="fb:admins" content="100002847892748" /><
# ...

# %%
#解析原始碼，取得焦點文章的標題
import bs4
root=bs4.BeautifulSoup(data,"html.parser")
titles=root.find_all("div",class_="focus_mobile")

for title in titles:
    title name=title.find("div",href).a.text.strip()
    print(article title)
# Out:
#   Input In [95]
#     title name=title.find("div",href).a.text.strip()
#           ^
# SyntaxError: invalid syntax
